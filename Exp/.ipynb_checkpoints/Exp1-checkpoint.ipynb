# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/telco_customer_churn.csv")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.1 MB

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)
for train_index, test_index in split.split(data, data["Churn"]):
    train_set = data.loc[train_index]
    test_set = data.loc[test_index]

# %%
train_set.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5634 entries, 3738 to 5639
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   str
#  1   gender            5634 non-null   str
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   str
#  4   Dependents        5634 non-null   str
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   str
#  7   MultipleLines     5634 non-null   str
#  8   InternetService   5634 non-null   str
#  9   OnlineSecurity    5634 non-null   str
#  10  OnlineBackup      5634 non-null   str
#  11  DeviceProtection  5634 non-null   str
#  12  TechSupport       5634 non-null   str
#  13  StreamingTV       5634 non-null   str
#  14  StreamingMovies   5634 non-null   str
#  15  Contract          5634 non-null   str
#  16  PaperlessBilling  5634 non-null   str
#  17  PaymentMethod     5634 non-null   str
#  18  MonthlyCharges    5634 non-null   float64
#  19  TotalCharges      5634 non-null   str
#  20  Churn             5634 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 968.3 KB

# %%
test_set.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1409 entries, 437 to 5613
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1409 non-null   str
#  1   gender            1409 non-null   str
#  2   SeniorCitizen     1409 non-null   int64
#  3   Partner           1409 non-null   str
#  4   Dependents        1409 non-null   str
#  5   tenure            1409 non-null   int64
#  6   PhoneService      1409 non-null   str
#  7   MultipleLines     1409 non-null   str
#  8   InternetService   1409 non-null   str
#  9   OnlineSecurity    1409 non-null   str
#  10  OnlineBackup      1409 non-null   str
#  11  DeviceProtection  1409 non-null   str
#  12  TechSupport       1409 non-null   str
#  13  StreamingTV       1409 non-null   str
#  14  StreamingMovies   1409 non-null   str
#  15  Contract          1409 non-null   str
#  16  PaperlessBilling  1409 non-null   str
#  17  PaymentMethod     1409 non-null   str
#  18  MonthlyCharges    1409 non-null   float64
#  19  TotalCharges      1409 non-null   str
#  20  Churn             1409 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 242.2 KB

# %%
compare = pd.DataFrame({
    "FULL":data["Churn"].value_counts(normalize=True),
    "TRAIN":train_set["Churn"].value_counts(normalize=True),
    "TEST":test_set["Churn"].value_counts(normalize=True),
})
print(compare)
# Out:
#           FULL     TRAIN      TEST
# Churn
# No     0.73463  0.734647  0.734564
# Yes    0.26537  0.265353  0.265436

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
class StrToNum():
    def __init__(self):
        pass
    def fit(self, X, y = None):
        return self
    def transform(self, X, y = None):
        Y = X.copy()
        Y["TotalCharges"] = pd.to_numeric(Y["TotalCharges"], errors="coerce")
        return Y

# %%
encoder = ColumnTransformer([
    ("ordinal", OrdinalEncoder(), ["gender"])
],
remainder="passthrough", verbose_feature_names_out = False
).set_output(transform="pandas")

# %%
pipeline = Pipeline([
    ("to_num", StrToNum()),
    ("encoder", encoder)
])

# %%
train_copy = train_set.copy()

# %%
pipeline.fit(train_copy)
# Out:
# Pipeline(steps=[('to_num', <__main__.StrToNum object at 0x00000216C69EF620>),
#                 ('encoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal', OrdinalEncoder(),
#                                                   ['gender'])],
#                                    verbose_feature_names_out=False))])

# %%
new_train = pipeline.transform(train_copy)

# %%
ord_enc = encoder.named_transformers_["ordinal"]
column_names = encoder.get_feature_names_out()
print(ord_enc.categories_)
# Out:
# [array(['Female', 'Male'], dtype=object)]

# %%
new_train = pd.DataFrame(data = new_train, columns=column_names)

# %%
new_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5634 entries, 3738 to 5639
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            5634 non-null   float64
#  1   customerID        5634 non-null   str
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   str
#  4   Dependents        5634 non-null   str
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   str
#  7   MultipleLines     5634 non-null   str
#  8   InternetService   5634 non-null   str
#  9   OnlineSecurity    5634 non-null   str
#  10  OnlineBackup      5634 non-null   str
#  11  DeviceProtection  5634 non-null   str
#  12  TechSupport       5634 non-null   str
#  13  StreamingTV       5634 non-null   str
#  14  StreamingMovies   5634 non-null   str
#  15  Contract          5634 non-null   str
#  16  PaperlessBilling  5634 non-null   str
#  17  PaymentMethod     5634 non-null   str
#  18  MonthlyCharges    5634 non-null   float64
#  19  TotalCharges      5626 non-null   float64
#  20  Churn             5634 non-null   str
# dtypes: float64(3), int64(2), str(16)
# memory usage: 968.3 KB

# %%
new_train.head(10)
# Out:
#       gender  customerID  SeniorCitizen Partner Dependents  tenure  \
# 3738     1.0  4950-BDEUX              0      No         No      35
# 3151     1.0  7993-NQLJE              0     Yes        Yes      15
# 4860     1.0  7321-ZNSLA              0     Yes        Yes      13
# 3867     0.0  4922-CVPDX              0     Yes         No      26
# 3810     1.0  2903-YYTBW              0     Yes        Yes       1
# 2666     1.0  8414-OOEEL              0      No        Yes      66
# 2645     0.0  8562-GHPPI              0      No         No       1
# 189      0.0  8017-UVSZU              0     Yes         No      40
# 5767     0.0  1972-XMUWV              0     Yes         No      65
# 2257     0.0  2054-PJOCK              0      No         No      60
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3738           No  No phone service             DSL                   No  ...
# 3151          Yes                No     Fiber optic                  Yes  ...
# 4860           No  No phone service             DSL                  Yes  ...
# 3867          Yes                No             DSL                   No  ...
# 3810          Yes                No             DSL                   No  ...
# 2666          Yes                No             DSL                   No  ...
# 2645          Yes                No              No  No internet service  ...
# 189           Yes               Yes             DSL                   No  ...
# 5767          Yes                No             DSL                   No  ...
# 2257          Yes               Yes             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3738                  Yes                   No                  Yes
# 3151                   No                   No                   No
# 4860                   No                  Yes                   No
# 3867                  Yes                   No                  Yes
# 3810                   No                   No                   No
# 2666                  Yes                  Yes                  Yes
# 2645  No internet service  No internet service  No internet service
# 189                    No                   No                   No
# 5767                   No                  Yes                  Yes
# 2257                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3738                  Yes  Month-to-month               No
# 3151                   No  Month-to-month               No
# 4860                   No        Two year               No
# 3867                  Yes        Two year              Yes
# 3810                   No  Month-to-month               No
# 2666                  Yes        Two year              Yes
# 2645  No internet service  Month-to-month               No
# 189                    No  Month-to-month               No
# 5767                   No        Two year              Yes
# 2257                  Yes        One year               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges  Churn
# 3738         Electronic check          49.20       1701.65     No
# 3151             Mailed check          75.10       1151.55     No
# 4860             Mailed check          40.55        590.35     No
# 3867  Credit card (automatic)          73.50       1905.70     No
# 3810         Electronic check          44.55         44.55     No
# 2666  Credit card (automatic)          79.50       5196.10     No
# 2645  Credit card (automatic)          19.80         19.80     No
# 189   Credit card (automatic)          56.60       2379.10     No
# 5767  Credit card (automatic)          59.80       3808.20     No
# 2257  Credit card (automatic)          80.55       4847.05     No
#
# [10 rows x 21 columns]

# %%
def showCategories(data):
    data = data.copy()
    table = {
        "Column":[],
        "Num Categories":[],
        "Categories":[],
    }
    cat_col = data.select_dtypes(include="str").columns
    for col in cat_col:
        if col == "customerID":
            continue
        values = data[col].dropna().unique()
        
        table["Column"].append(col)
        table["Num Categories"].append(len(values))
        table["Categories"].append(values)

    pd.set_option("display.max_colwidth", None)
    return pd.DataFrame(table)

showCategories(new_train)
# Out:
#               Column  Num Categories  \
# 0            Partner               2
# 1         Dependents               2
# 2       PhoneService               2
# 3      MultipleLines               3
# 4    InternetService               3
# 5     OnlineSecurity               3
# 6       OnlineBackup               3
# 7   DeviceProtection               3
# 8        TechSupport               3
# 9        StreamingTV               3
# 10   StreamingMovies               3
# 11          Contract               3
# 12  PaperlessBilling               2
# 13     PaymentMethod               4
# 14             Churn               2
#
#                                                                               Categories
# 0                                                                              [No, Yes]
# 1                                                                              [No, Yes]
# 2                                                                              [No, Yes]
# 3                                                            [No phone service, No, Yes]
# 4                                                                 [DSL, Fiber optic, No]
# 5                                                         [No, Yes, No internet service]
# 6                                                         [No, Yes, No internet service]
# 7                                                         [Yes, No, No internet service]
# 8                                                         [No, Yes, No internet service]
# 9                                                         [Yes, No, No internet service]
# 10                                                        [Yes, No, No internet service]
# 11                                                  [Month-to-month, Two year, One year]
# 12                                                                             [No, Yes]
# 13  [Electronic check, Mailed check, Credit card (automatic), Bank transfer (automatic)]
# 14                                                                             [No, Yes]

# %%
import math

def clusteredChart(y, data, grid_col=2, size=(12, 4)):
    cols = data.select_dtypes(include="str").columns

    n = len(cols)
    rows = math.ceil(n / grid_col)

    fig, axes = plt.subplots(rows, grid_col, figsize=(size[0], size[1] * rows))
    axes = axes.flatten()

    for i, col in enumerate(cols):
        if col == "customerID":
            continue
        chart = (
            data.groupby([col, y])
            .size()
            .unstack(fill_value = 0).apply(lambda x: x/x.sum(), axis = 1)*100
        )

        chart.plot(kind="bar", ax=axes[i])
        axes[i].set_title(f"{col} vs {y}")
        axes[i].tick_params(axis="x", rotation=45)

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
def combinedData(data, y):
    pd_result = {
        "Yes":[],
        "No":[],
    }
    cols = data.select_dtypes(include="str").columns
    for col in cols:
        if col == "customerID": continue
        count_table = data.groupby([col, y]).size().unstack()
        percentage_table = data.groupby([col, y]).size().unstack(fill_value=0).apply(lambda x: x / x.sum(), axis = 1)*100

        
        result = pd.concat(
            [count_table.add_prefix("count_"), 
             percentage_table.add_suffix("_%")],
            axis = 1)

        print(f"\n==={col}===")
        print(result)

combinedData(new_train, "Churn")
# Out:
# ===Partner===
# Churn    count_No  count_Yes       No_%      Yes_%
# Partner
# No           1953        952  67.228916  32.771084
# Yes          2186        543  80.102602  19.897398
#
# ===Dependents===
# Churn       count_No  count_Yes       No_%      Yes_%
# Dependents
# No              2715       1240  68.647282  31.352718
# Yes             1424        255  84.812388  15.187612
#
# ===PhoneService===
# Churn         count_No  count_Yes       No_%      Yes_%
# PhoneService
# No                 424        135  75.849732  24.150268
# Yes               3715       1360  73.201970  26.798030
#
# ===MultipleLines===
# Churn             count_No  count_Yes       No_%      Yes_%
# MultipleLines
# No                    2013        672  74.972067  25.027933
# No phone service       424        135  75.849732  24.150268
# Yes                   1702        688  71.213389  28.786611
#
# ===InternetService===
# Churn            count_No  count_Yes       No_%      Yes_%
# InternetService
# DSL                  1575        362  81.311306  18.688694
# Fiber optic          1438       1045  57.913814  42.086186
# No                   1126         88  92.751236   7.248764
#
# ===OnlineSecurity===
# Churn                count_No  count_Yes       No_%      Yes_%
# OnlineSecurity
# No                       1624       1173  58.062210  41.937790
# No internet service      1126         88  92.751236   7.248764
# Yes                      1389        234  85.582255  14.417745
#
# ===OnlineBackup===
# Churn                count_No  count_Yes       No_%      Yes_%
# OnlineBackup
# No                       1462        980  59.868960  40.131040
# No internet service      1126         88  92.751236   7.248764
# Yes                      1551        427  78.412538  21.587462
#
# ===DeviceProtection===
# Churn                count_No  count_Yes       No_%      Yes_%
# DeviceProtection
# No                       1509        963  61.043689  38.956311
# No internet service      1126         88  92.751236   7.248764
# Yes                      1504        444  77.207392  22.792608
#
# ===TechSupport===
# Churn                count_No  count_Yes       No_%      Yes_%
# TechSupport
# No                       1614       1157  58.246121  41.753879
# No internet service      1126         88  92.751236   7.248764
# Yes                      1399        250  84.839297  15.160703
#
# ===StreamingTV===
# Churn                count_No  count_Yes       No_%      Yes_%
# StreamingTV
# No                       1489        737  66.891285  33.108715
# No internet service      1126         88  92.751236   7.248764
# Yes                      1524        670  69.462170  30.537830
#
# ===StreamingMovies===
# Churn                count_No  count_Yes       No_%      Yes_%
# StreamingMovies
# No                       1472        745  66.396031  33.603969
# No internet service      1126         88  92.751236   7.248764
# Yes                      1541        662  69.950068  30.049932
#
# ===Contract===
# Churn           count_No  count_Yes       No_%      Yes_%
# Contract
# Month-to-month      1776       1326  57.253385  42.746615
# One year            1043        130  88.917306  11.082694
# Two year            1320         39  97.130243   2.869757
#
# ===PaperlessBilling===
# Churn             count_No  count_Yes       No_%      Yes_%
# PaperlessBilling
# No                    1934        369  83.977421  16.022579
# Yes                   2205       1126  66.196337  33.803663
#
# ===PaymentMethod===
# Churn                      count_No  count_Yes       No_%      Yes_%
# PaymentMethod
# Bank transfer (automatic)      1043        201  83.842444  16.157556
# Credit card (automatic)        1032        181  85.078318  14.921682
# Electronic check               1026        865  54.257007  45.742993
# Mailed check                   1038        248  80.715397  19.284603
#
# ===Churn===
# Churn  count_No  count_Yes   No_%  Yes_%
# Churn
# No       4139.0        NaN  100.0    0.0
# Yes         NaN     1495.0    0.0  100.0

# %%
churn_vs_payment = new_train.groupby("PaymentMethod")["Churn"].value_counts(normalize = True).unstack() * 100
print(churn_vs_payment)
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.842444  16.157556
# Credit card (automatic)    85.078318  14.921682
# Electronic check           54.257007  45.742993
# Mailed check               80.715397  19.284603

# %%
churn_vs_payment.plot(kind = "bar")
# Out:
# <Axes: xlabel='PaymentMethod'>

# %%
clusteredChart("Churn", new_train, 2, (12, 4))
